# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.expand_frame_repr',False)
pd.set_option('max_colwidth',-1)
df = pd.read_csv('IPL_ball_by_ball_updated.csv')

# %%
df.head()
# Out:
#    match_id   season start_date                  venue  innings  ball           batting_team                 bowling_team      striker  non_striker   bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed
# 0  335982    2007/08  4/18/2008  M Chinnaswamy Stadium  1        0.1   Kolkata Knight Riders  Royal Challengers Bangalore  SC Ganguly   BB McCullum  P Kumar  0             1      NaN    NaN      NaN    1.0     NaN       NaN         NaN             NaN                NaN
# 1  335982    2007/08  4/18/2008  M Chinnaswamy Stadium  1        0.2   Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum  SC Ganguly   P Kumar  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN
# ...

# %% [raw]
# df.head()

# %%
df['striker'].unique()
# Out:
# array(['SC Ganguly', 'BB McCullum', 'RT Ponting', 'DJ Hussey',
#        'Mohammad Hafeez', 'R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis',
#        'CL White', 'MV Boucher', 'B Akhil', 'AA Noffke', 'P Kumar',
#        'Z Khan', 'SB Joshi', 'PA Patel', 'ML Hayden', 'MEK Hussey',
#        'MS Dhoni', 'SK Raina', 'JDP Oram', 'S Badrinath', 'K Goel',
#        'JR Hopes', 'KC Sangakkara', 'Yuvraj Singh', 'SM Katich',
#        'IK Pathan', 'T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif',
#        'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne',
#        'SK Trivedi', 'G Gambhir', 'V Sehwag', 'S Dhawan', 'AC Gilchrist',
#        'Y Venugopal Rao', 'VVS Laxman', 'A Symonds', 'RG Sharma',
#        'SB Styris', 'AS Yadav', 'SB Bangar', 'WPUJC Vaas', 'RP Singh',
#        'WP Saha', 'LR Shukla', 'L Ronchi', 'ST Jayasuriya', 'DJ Thornely',
#        'RV Uthappa', 'PR Shah', 'AM Nayar', 'SM Pollock',
#        'Harbhajan Singh', 'S Chanderpaul', 'LRPL Taylor',
# ...

# %%
df.dtypes
# Out:
# match_id                  int64
# season                    object
# start_date                object
# venue                     object
# innings                   int64
# ball                      float64
# batting_team              object
# bowling_team              object
# striker                   object
# non_striker               object
# bowler                    object
# runs_off_bat              int64
# extras                    int64
# wides                     float64
# noballs                   float64
# byes                      float64
# legbyes                   float64
# penalty                   float64
# wicket_type               object
# player_dismissed          object
# other_wicket_type         float64
# other_player_dismissed    float64
# dtype: object

# %%
df['start_date'] = pd.to_datetime(df['start_date'])

# %%
df.dtypes
# Out:
# match_id                  int64
# season                    object
# start_date                datetime64[ns]
# venue                     object
# innings                   int64
# ball                      float64
# batting_team              object
# bowling_team              object
# striker                   object
# non_striker               object
# bowler                    object
# runs_off_bat              int64
# extras                    int64
# wides                     float64
# noballs                   float64
# byes                      float64
# legbyes                   float64
# penalty                   float64
# wicket_type               object
# player_dismissed          object
# other_wicket_type         float64
# other_player_dismissed    float64
# dtype: object

# %%
df['year'] = df['start_date'].dt.year

# %%
df.head()
# Out:
#    match_id   season start_date                  venue  innings  ball           batting_team                 bowling_team      striker  non_striker   bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed  year
# 0  335982    2007/08 2008-04-18  M Chinnaswamy Stadium  1        0.1   Kolkata Knight Riders  Royal Challengers Bangalore  SC Ganguly   BB McCullum  P Kumar  0             1      NaN    NaN      NaN    1.0     NaN       NaN         NaN             NaN                NaN                      2008
# 1  335982    2007/08 2008-04-18  M Chinnaswamy Stadium  1        0.2   Kolkata Knight Riders  Royal Challengers Bangalore  BB McCullum  SC Ganguly   P Kumar  0             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN                      2008
# ...

# %%
df.columns
# Out:
# Index(['match_id', 'season', 'start_date', 'venue', 'innings', 'ball',
#        'batting_team', 'bowling_team', 'striker', 'non_striker', 'bowler',
#        'runs_off_bat', 'extras', 'wides', 'noballs', 'byes', 'legbyes',
#        'penalty', 'wicket_type', 'player_dismissed', 'other_wicket_type',
#        'other_player_dismissed', 'year'],
#       dtype='object')

# %%
df['year'].unique()
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2019,
#        2018, 2020, 2021, 2022], dtype=int64)

# %%
dhoni_df = df[df['striker'] == 'MS Dhoni']

# %%
dhoni_df.shape
# Out:
# (3802, 23)

# %% [markdown]
# ##### Dhoni Analysis

# %%
###Run Scored
###Strike Rate
###Fours
###Sixes
###Dots

# %%
w1 = df.groupby(['year','striker'])['runs_off_bat'].sum().reset_index()

# %%
w1 = w1[w1['runs_off_bat'] > 600 ]

# %%
w1
# Out:
#       year         striker  runs_off_bat
# 115   2008  SE Marsh        616
# 446   2010  SR Tendulkar    618
# 502   2011  CH Gayle        608
# 684   2012  CH Gayle        733
# 852   2013  CH Gayle        720
# 910   2013  MEK Hussey      733
# 983   2013  V Kohli         639
# 1088  2014  RV Uthappa      660
# 1256  2016  AB de Villiers  687
# 1278  2016  DA Warner       848
# 1383  2016  V Kohli         973
# 1422  2017  DA Warner       641
# 1542  2018  AT Rayudu       602
# 1592  2018  KL Rahul        659
# 1594  2018  KS Williamson   735
# 1636  2018  RR Pant         684
# 1694  2019  DA Warner       692
# 1866  2020  KL Rahul        676
# 1912  2020  S Dhawan        618
# 1979  2021  F du Plessis    633
# 2007  2021  KL Rahul        626
# 2051  2021  RD Gaikwad      635
# 2144  2022  JC Buttler      863
# 2160  2022  KL Rahul        616

# %%
w2 = w1.groupby('striker')['runs_off_bat'].count().sort_values(ascending=False).reset_index()

# %%
w2
# Out:
#            striker  runs_off_bat
# 0   KL Rahul        4
# 1   CH Gayle        3
# 2   DA Warner       3
# 3   V Kohli         2
# 4   AB de Villiers  1
# 5   AT Rayudu       1
# 6   F du Plessis    1
# 7   JC Buttler      1
# 8   KS Williamson   1
# 9   MEK Hussey      1
# 10  RD Gaikwad      1
# 11  RR Pant         1
# 12  RV Uthappa      1
# 13  S Dhawan        1
# 14  SE Marsh        1
# 15  SR Tendulkar    1

# %%
dhoni_df.head()
# Out:
#       match_id   season start_date                                       venue  innings  ball         batting_team     bowling_team   striker non_striker     bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed  year
# 265   335983    2007/08 2008-04-19  Punjab Cricket Association Stadium, Mohali  1        6.3   Chennai Super Kings  Kings XI Punjab  MS Dhoni  MEK Hussey  IK Pathan  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN                      2008
# 268   335983    2007/08 2008-04-19  Punjab Cricket Association Stadium, Mohali  1        6.6   Chennai Super Kings  Kings XI Punjab  MS Dhoni  MEK Hussey  IK Pathan  1             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN                      2008
# ...

# %%
d1 = dhoni_df.groupby('year')['runs_off_bat'].sum().reset_index()

# %%
d1
# Out:
#     year  runs_off_bat
# 0   2008  414
# 1   2009  332
# 2   2010  287
# 3   2011  392
# 4   2012  358
# 5   2013  461
# 6   2014  371
# 7   2015  372
# 8   2016  284
# 9   2017  290
# 10  2018  455
# 11  2019  416
# 12  2020  200
# 13  2021  114
# 14  2022  232

# %%
d2 = dhoni_df.groupby('year')['ball'].count().reset_index()

# %%
d2
# Out:
#     year  ball
# 0   2008  319
# 1   2009  270
# 2   2010  215
# 3   2011  247
# 4   2012  283
# 5   2013  298
# 6   2014  258
# 7   2015  309
# 8   2016  220
# 9   2017  261
# 10  2018  321
# 11  2019  317
# 12  2020  175
# 13  2021  111
# 14  2022  198

# %%
dhoni_four = dhoni_df[dhoni_df['runs_off_bat']==4]

# %%
dhoni_four.head()
# Out:
#       match_id   season start_date                            venue  innings  ball         batting_team           bowling_team   striker non_striker       bowler  runs_off_bat  extras  wides  noballs  byes  legbyes  penalty wicket_type player_dismissed  other_wicket_type  other_player_dismissed  year
# 1720  335989    2007/08 2008-04-23  MA Chidambaram Stadium, Chepauk  1        15.2  Chennai Super Kings  Mumbai Indians         MS Dhoni  ML Hayden   DJ Bravo     4             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN                      2008
# 1722  335989    2007/08 2008-04-23  MA Chidambaram Stadium, Chepauk  1        15.4  Chennai Super Kings  Mumbai Indians         MS Dhoni  ML Hayden   DJ Bravo     4             0      NaN    NaN      NaN   NaN      NaN       NaN         NaN             NaN                NaN                      2008
# ...

# %%
d3 = dhoni_four.groupby('year')['runs_off_bat'].count().reset_index()

# %%
d3
# Out:
#     year  runs_off_bat
# 0   2008  38
# 1   2009  22
# 2   2010  26
# 3   2011  25
# 4   2012  26
# 5   2013  32
# 6   2014  22
# 7   2015  27
# 8   2016  18
# 9   2017  15
# 10  2018  24
# 11  2019  22
# 12  2020  16
# 13  2021  12
# 14  2022  21

# %%
dhoni_six = dhoni_df[dhoni_df['runs_off_bat']==6]

# %%
d4 = dhoni_six.groupby('year')['runs_off_bat'].count().reset_index()

# %%
d4
# Out:
#     year  runs_off_bat
# 0   2008  15
# 1   2009  9
# 2   2010  8
# 3   2011  23
# 4   2012  9
# 5   2013  25
# 6   2014  20
# 7   2015  17
# 8   2016  14
# 9   2017  16
# 10  2018  30
# 11  2019  23
# 12  2020  7
# 13  2021  3
# 14  2022  10

# %%
dhoni_dot = dhoni_df[dhoni_df['runs_off_bat']==0]

# %%
d5 = dhoni_dot.groupby('year')['runs_off_bat'].count().reset_index()

# %%
d5
# Out:
#     year  runs_off_bat
# 0   2008  124
# 1   2009  75
# 2   2010  66
# 3   2011  69
# 4   2012  87
# 5   2013  94
# 6   2014  85
# 7   2015  127
# 8   2016  82
# 9   2017  116
# 10  2018  110
# 11  2019  117
# 12  2020  73
# 13  2021  53
# 14  2022  92

# %%
d3 = d3.rename(columns = {'runs_off_bat' : 'four'})

# %%
d3
# Out:
#     year  four
# 0   2008  38
# 1   2009  22
# 2   2010  26
# 3   2011  25
# 4   2012  26
# 5   2013  32
# 6   2014  22
# 7   2015  27
# 8   2016  18
# 9   2017  15
# 10  2018  24
# 11  2019  22
# 12  2020  16
# 13  2021  12
# 14  2022  21

# %%
d4 = d4.rename(columns = {'runs_off_bat' : 'six'})

# %%
d5 = d5.rename(columns = {'runs_off_bat' : 'dot'})

# %%
d6 = d1.merge(d2,on='year',how='right').merge(d3,on='year',how='right').merge(d4,on='year',how='right').merge(d5,on='year',how='right')

# %%
d6
# Out:
#     year  runs_off_bat  ball  four  six  dot
# 0   2008  414           319   38    15   124
# 1   2009  332           270   22    9    75
# 2   2010  287           215   26    8    66
# 3   2011  392           247   25    23   69
# 4   2012  358           283   26    9    87
# 5   2013  461           298   32    25   94
# 6   2014  371           258   22    20   85
# 7   2015  372           309   27    17   127
# 8   2016  284           220   18    14   82
# 9   2017  290           261   15    16   116
# 10  2018  455           321   24    30   110
# 11  2019  416           317   22    23   117
# 12  2020  200           175   16    7    73
# 13  2021  114           111   12    3    53
# 14  2022  232           198   21    10   92

# %%
d6['strike_rate'] = d6['runs_off_bat'] / d6['ball'] * 100

# %%
d6
# Out:
#     year  runs_off_bat  ball  four  six  dot  strike_rate
# 0   2008  414           319   38    15   124  129.780564
# 1   2009  332           270   22    9    75   122.962963
# 2   2010  287           215   26    8    66   133.488372
# 3   2011  392           247   25    23   69   158.704453
# 4   2012  358           283   26    9    87   126.501767
# 5   2013  461           298   32    25   94   154.697987
# 6   2014  371           258   22    20   85   143.798450
# 7   2015  372           309   27    17   127  120.388350
# 8   2016  284           220   18    14   82   129.090909
# 9   2017  290           261   15    16   116  111.111111
# 10  2018  455           321   24    30   110  141.744548
# 11  2019  416           317   22    23   117  131.230284
# 12  2020  200           175   16    7    73   114.285714
# 13  2021  114           111   12    3    53   102.702703
# 14  2022  232           198   21    10   92   117.171717

# %%
d6['total_boundaries'] = d6['four'] + d6['six']

# %%
d6
# Out:
#     year  runs_off_bat  ball  four  six  dot  strike_rate  total_boundaries
# 0   2008  414           319   38    15   124  129.780564   53
# 1   2009  332           270   22    9    75   122.962963   31
# 2   2010  287           215   26    8    66   133.488372   34
# 3   2011  392           247   25    23   69   158.704453   48
# 4   2012  358           283   26    9    87   126.501767   35
# 5   2013  461           298   32    25   94   154.697987   57
# 6   2014  371           258   22    20   85   143.798450   42
# 7   2015  372           309   27    17   127  120.388350   44
# 8   2016  284           220   18    14   82   129.090909   32
# 9   2017  290           261   15    16   116  111.111111   31
# 10  2018  455           321   24    30   110  141.744548   54
# 11  2019  416           317   22    23   117  131.230284   45
# 12  2020  200           175   16    7    73   114.285714   23
# 13  2021  114           111   12    3    53   102.702703   15
# ...

# %%
d6['dot_ball_percent'] = d6['dot'] / d6['ball'] * 100

# %%
d6['dot_ball_percent'] = d6['dot_ball_percent'].apply(np.ceil)

# %%
d6['dot_ball_percent'] = np.round(d6['dot_ball_percent'],decimals = 0)

# %%
d6['dot_ball_percent'] = d6['dot_ball_percent'].astype('int')

# %%
d6['strike_rate'] = np.round(d6['strike_rate'],decimals = 2 )

# %%
d6
# Out:
#     year  runs_off_bat  ball  four  six  dot  strike_rate  total_boundaries  dot_ball_percent
# 0   2008  414           319   38    15   124  129.78       53                39
# 1   2009  332           270   22    9    75   122.96       31                28
# 2   2010  287           215   26    8    66   133.49       34                31
# 3   2011  392           247   25    23   69   158.70       48                28
# 4   2012  358           283   26    9    87   126.50       35                31
# 5   2013  461           298   32    25   94   154.70       57                32
# 6   2014  371           258   22    20   85   143.80       42                33
# 7   2015  372           309   27    17   127  120.39       44                42
# 8   2016  284           220   18    14   82   129.09       32                38
# 9   2017  290           261   15    16   116  111.11       31                45
# 10  2018  455           321   24    30   110  141.74       54                35
# ...

# %% [markdown]
# ###### Dhoni Overall Stats:

# %%
print("Runs:",dhoni_df['runs_off_bat'].sum() )
# Out:
# Runs: 4978

# %%
print("Balls Faced:",dhoni_df['ball'].count() )
# Out:
# Balls Faced: 3802

# %%
import math

# %%
s = (dhoni_df['runs_off_bat'].sum() /dhoni_df['ball'].count( )) * 100

# %%
print("Strike_rate:", end=" ")
print(round(s,2))
# Out:
# Strike_rate: 130.93

# %%
print("Sixes:",dhoni_six['ball'].count())
# Out:
# Sixes: 229

# %%
print("Fours:",dhoni_four['ball'].count())
# Out:
# Fours: 346

# %%
dhoni_df = df[df['striker']=='MS Dhoni']

# %%
t = dhoni_df.groupby('match_id')['runs_off_bat'].sum().reset_index()

# %%
t1 = t[t['runs_off_bat'] > 29 ]

# %%
print('No_of_30s:',t1['runs_off_bat'].count() )
# Out:
# No_of_30s: 64

# %% [markdown]
# ### Overall Stats

# %%
o = df.groupby('striker')['runs_off_bat'].sum().sort_values(ascending=False).reset_index()

# %%
o = o.rename(columns={'runs_off_bat':'Runs_Scored'})

# %%
o.head()
# Out:
#      striker  Runs_Scored
# 0  V Kohli    6634
# 1  S Dhawan   6244
# 2  DA Warner  5883
# 3  RG Sharma  5881
# 4  SK Raina   5536

# %%
o1 = df.groupby('striker')['ball'].count().sort_values(ascending=False).reset_index()

# %%
o1.head()
# Out:
#      striker  ball
# 0  V Kohli    5266
# 1  S Dhawan   5083
# 2  RG Sharma  4632
# 3  DA Warner  4313
# 4  SK Raina   4177

# %%
o_six = df[df['runs_off_bat'] == 6 ]

# %%
o2 = o_six.groupby('striker')['runs_off_bat'].count().sort_values(ascending=False).reset_index()

# %%
o2 = o2.rename(columns={'runs_off_bat':'Sixes'})

# %%
o2.head()
# Out:
#           striker  Sixes
# 0  CH Gayle        359
# 1  AB de Villiers  253
# 2  RG Sharma       241
# 3  MS Dhoni        229
# 4  KA Pollard      224

# %%
o_four = df[df['runs_off_bat'] == 4 ]

# %%
o3 = o_four.groupby('striker')['runs_off_bat'].count().sort_values(ascending=False).reset_index()

# %%
o3 = o3.rename(columns={'runs_off_bat':'Fours'})

# %%
o3.head(15)
# Out:
#            striker  Fours
# 0   S Dhawan        701
# 1   V Kohli         581
# 2   DA Warner       577
# 3   RG Sharma       519
# 4   SK Raina        506
# 5   G Gambhir       492
# 6   RV Uthappa      481
# 7   AM Rahane       431
# 8   KD Karthik      426
# 9   AB de Villiers  414
# 10  CH Gayle        408
# 11  SR Watson       377
# 12  PA Patel        365
# 13  AT Rayudu       349
# 14  MS Dhoni        346

# %%
o4 = o.merge(o1,on='striker',how='right').merge(o2,on='striker',how='right').merge(o3,on='striker',how='right')

# %%
o4.head()
# Out:
#      striker  Runs_Scored    ball  Sixes  Fours
# 0  S Dhawan   6244.0       5083.0  137.0  701
# 1  V Kohli    6634.0       5266.0  219.0  581
# 2  DA Warner  5883.0       4313.0  216.0  577
# 3  RG Sharma  5881.0       4632.0  241.0  519
# 4  SK Raina   5536.0       4177.0  204.0  506

# %%
o4.dtypes
# Out:
# striker        object
# Runs_Scored    float64
# ball           float64
# Sixes          float64
# Fours          int64
# dtype: object

# %%
o4['Sixes'].unique()
# Out:
# array([137., 219., 216., 241., 204.,  59., 182.,  80., 134., 253., 359.,
#        190.,  49., 164., 229., 106., 109.,  29., 130.,  84., 158., 135.,
#         78.,  28., 161., 129.,  44.,  91., 117.,  92.,  99.,  76.,  60.,
#        224., 149.,  40., 127.,  52.,  27.,  55., 111.,  47.,  64.,  90.,
#         68.,  37., 113.,  85.,  39.,  24., 175.,  42.,  36.,  66.,  79.,
#         43.,  50.,  63.,   9.,  23.,  38.,  31.,  48.,  32.,  56.,  53.,
#         41.,  21.,  19.,  54.,  46.,  35.,  25.,  22.,  20.,  13.,  10.,
#         26.,  11.,  18.,  65.,   4.,   6.,  16.,   5.,   3.,   2.,   7.,
#          8.,  15.,  12.,   1.,  17.,  14.,  nan])

# %%
o4.dropna()
# Out:
#                striker  Runs_Scored    ball  Sixes  Fours
# 0    S Dhawan           6244.0       5083.0  137.0  701
# 1    V Kohli            6634.0       5266.0  219.0  581
# 2    DA Warner          5883.0       4313.0  216.0  577
# 3    RG Sharma          5881.0       4632.0  241.0  519
# 4    SK Raina           5536.0       4177.0  204.0  506
# 5    G Gambhir          4217.0       3524.0  59.0   492
# 6    RV Uthappa         4954.0       3927.0  182.0  481
# 7    AM Rahane          4074.0       3465.0  80.0   431
# 8    KD Karthik         4377.0       3386.0  134.0  426
# 9    AB de Villiers     5181.0       3487.0  253.0  414
# 10   CH Gayle           4997.0       3516.0  359.0  408
# 11   SR Watson          3880.0       2892.0  190.0  377
# 12   PA Patel           2848.0       2442.0  49.0   365
# 13   AT Rayudu          4190.0       3375.0  164.0  349
# 14   MS Dhoni           4978.0       3802.0  229.0  346
# 15   V Sehwag           2728.0       1833.0  106.0  334
# ...

# %%
o4['Sixes'].unique()
# Out:
# array([137., 219., 216., 241., 204.,  59., 182.,  80., 134., 253., 359.,
#        190.,  49., 164., 229., 106., 109.,  29., 130.,  84., 158., 135.,
#         78.,  28., 161., 129.,  44.,  91., 117.,  92.,  99.,  76.,  60.,
#        224., 149.,  40., 127.,  52.,  27.,  55., 111.,  47.,  64.,  90.,
#         68.,  37., 113.,  85.,  39.,  24., 175.,  42.,  36.,  66.,  79.,
#         43.,  50.,  63.,   9.,  23.,  38.,  31.,  48.,  32.,  56.,  53.,
#         41.,  21.,  19.,  54.,  46.,  35.,  25.,  22.,  20.,  13.,  10.,
#         26.,  11.,  18.,  65.,   4.,   6.,  16.,   5.,   3.,   2.,   7.,
#          8.,  15.,  12.,   1.,  17.,  14.,  nan])

# %%
o4.head()
# Out:
#      striker  Runs_Scored    ball  Sixes  Fours
# 0  S Dhawan   6244.0       5083.0  137.0  701
# 1  V Kohli    6634.0       5266.0  219.0  581
# 2  DA Warner  5883.0       4313.0  216.0  577
# 3  RG Sharma  5881.0       4632.0  241.0  519
# 4  SK Raina   5536.0       4177.0  204.0  506

# %%
o4.head(10)
# Out:
#           striker  Runs_Scored    ball  Sixes  Fours
# 0  S Dhawan        6244.0       5083.0  137.0  701
# 1  V Kohli         6634.0       5266.0  219.0  581
# 2  DA Warner       5883.0       4313.0  216.0  577
# 3  RG Sharma       5881.0       4632.0  241.0  519
# 4  SK Raina        5536.0       4177.0  204.0  506
# 5  G Gambhir       4217.0       3524.0  59.0   492
# 6  RV Uthappa      4954.0       3927.0  182.0  481
# 7  AM Rahane       4074.0       3465.0  80.0   431
# 8  KD Karthik      4377.0       3386.0  134.0  426
# 9  AB de Villiers  5181.0       3487.0  253.0  414

# %%
o4 = o4.dropna(subset=['Sixes'])

# %%
o4['Sixes'].unique()
# Out:
# array([137., 219., 216., 241., 204.,  59., 182.,  80., 134., 253., 359.,
#        190.,  49., 164., 229., 106., 109.,  29., 130.,  84., 158., 135.,
#         78.,  28., 161., 129.,  44.,  91., 117.,  92.,  99.,  76.,  60.,
#        224., 149.,  40., 127.,  52.,  27.,  55., 111.,  47.,  64.,  90.,
#         68.,  37., 113.,  85.,  39.,  24., 175.,  42.,  36.,  66.,  79.,
#         43.,  50.,  63.,   9.,  23.,  38.,  31.,  48.,  32.,  56.,  53.,
#         41.,  21.,  19.,  54.,  46.,  35.,  25.,  22.,  20.,  13.,  10.,
#         26.,  11.,  18.,  65.,   4.,   6.,  16.,   5.,   3.,   2.,   7.,
#          8.,  15.,  12.,   1.,  17.,  14.])

# %%
o4['Sixes'] = o4['Sixes'].astype('int')

# %%
o4['Runs_Scored'] = o4['Runs_Scored'].astype('int')
o4['ball'] = o4['ball'].astype('int')

# %%
o4.head()
# Out:
#      striker  Runs_Scored  ball  Sixes  Fours
# 0  S Dhawan   6244         5083  137    701
# 1  V Kohli    6634         5266  219    581
# 2  DA Warner  5883         4313  216    577
# 3  RG Sharma  5881         4632  241    519
# 4  SK Raina   5536         4177  204    506

# %%
o4['Strike_rate'] = o4['Runs_Scored'] / o4['ball'] * 100

# %%
o4.head()
# Out:
#      striker  Runs_Scored  ball  Sixes  Fours  Strike_rate
# 0  S Dhawan   6244         5083  137    701    122.840842
# 1  V Kohli    6634         5266  219    581    125.977972
# 2  DA Warner  5883         4313  216    577    136.401577
# 3  RG Sharma  5881         4632  241    519    126.964594
# 4  SK Raina   5536         4177  204    506    132.535312

# %%
o4['Strike_rate'] = np.round(o4['Strike_rate'],decimals=2)

# %%
# Out:
#            striker  Runs_Scored  ball  Sixes  Fours  Strike_rate
# 0   S Dhawan        6244         5083  137    701    122.84
# 1   V Kohli         6634         5266  219    581    125.98
# 2   DA Warner       5883         4313  216    577    136.40
# 3   RG Sharma       5881         4632  241    519    126.96
# 4   SK Raina        5536         4177  204    506    132.54
# 5   G Gambhir       4217         3524  59     492    119.67
# 6   RV Uthappa      4954         3927  182    481    126.15
# 7   AM Rahane       4074         3465  80     431    117.58
# 8   KD Karthik      4377         3386  134    426    129.27
# 9   AB de Villiers  5181         3487  253    414    148.58
# 10  CH Gayle        4997         3516  359    408    142.12
# 11  SR Watson       3880         2892  190    377    134.16
# 12  PA Patel        2848         2442  49     365    116.63
# 13  AT Rayudu       4190         3375  164    349    124.15
# 14  MS Dhoni        4978         3802  229    346    130.93

# %%
o4.to_csv('All_time_Ipl.csv')

# %%
d6.to_csv('Dhoni_stats_byYear.csv')
